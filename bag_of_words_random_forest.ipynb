# %% [markdown]
# # Time price prediction

# %% [markdown]
# # Random Forest

# %% [markdown]
# ### TO DO: integrate all data, split into test/train cases, separate functions into their own .py files

# %%
import pandas as pd
import ijson
import json
import gensim
import re
import numpy as np
import os
import nltk.data

# from os import walk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Test articles from 2 days

# %%
Jan25_article = 'Earnings_Preview_Facebook_Inc_NASDAQFB_moved_up_10_times_out_of_last_17_quarters__The_Independent_Republic.json'
Jan26_article = 'Facebook_Inc_FB_Hires_Former_Google_Exec_to_Lead_Oculus.json'

# %% [markdown]
# ### Create dataframe from JSON files

# %%
articlelist = [Jan25_article, Jan26_article]
articlelist
# Out:
# ['Earnings_Preview_Facebook_Inc_NASDAQFB_moved_up_10_times_out_of_last_17_quarters__The_Independent_Republic.json',
#  'Facebook_Inc_FB_Hires_Former_Google_Exec_to_Lead_Oculus.json']

# %%
def read_Google_articles(articlelist, path):
    """ 
    Converts Google News JSON file into a data frame. Takes in
    a .json file and returns a dataframe using the json's dictionary-like
    structure 
    """
    
    with open(path + articlelist[0],'r') as first:
        firstdict = json.load(first)
        combined_df = pd.DataFrame.from_dict(firstdict, orient = 'index')
        combined_df = combined_df.T
    
    for article in articlelist:
        with open(path + article, 'r') as fin:
            mydict = json.load(fin)
        current_df = pd.DataFrame.from_dict(mydict, orient = 'index')
        current_df = current_df.T
        combined_df = combined_df.append(current_df, ignore_index=True)
    
    # USE CONCAT WITH .APPEND DOESN'T WORK!!!
#     final_df = pd.concat([combined_df, current_df])
        
    return combined_df

# %% [markdown]
# # Test on 2 files

# %%
path = ''
all_articles_df = read_Google_articles(articlelist, path)
all_articles_df
# Out:
#                                                 body          category  \
# 0  Facebook, Inc. (NASDAQ:FB) is projected to dec...          Facebook
# 1  Facebook, Inc. (NASDAQ:FB) is projected to dec...          Facebook
# 2  Facebook Inc’s (NASDAQ: ) virtual reality divi...  Facebook 1-26-17
#
#                                                title
# 0  Earnings Preview: Facebook, Inc. (NASDAQ:FB) m...
# 1  Earnings Preview: Facebook, Inc. (NASDAQ:FB) m...
# 2  Facebook Inc (FB) Hires Former Google Exec to ...

# %% [markdown]
# ### Preprocess these articles

# %%
def preprocess_article_content(text_df):
    """
    Simple preprocessing pipeline which uses RegExp, sets basic token requirements, and removes stop words.
    Set up to work with df files created from JSONs
    """
    print 'preprocessing article text...'

    # tokenizer, stops, and stemmer
    tokenizer = RegexpTokenizer(r'\w+')
    stop_words = set(stopwords.words('english'))  # can add more stop words to this set
    stemmer = SnowballStemmer('english')

    # process articles
    article_list = []
    for row, article in enumerate(text_df['body']):
        cleaned_tokens = []

        letters_only = re.sub("[^a-zA-Z]", " ", article)
        lower_case = letters_only.lower()
        tokens = tokenizer.tokenize(lower_case)

    #         tokens = tokenizer.tokenize(article.decode('utf-8').lower())
        for token in tokens:
            if token not in stop_words:
                if len(token) > 0 and len(token) < 20: # removes non words
                    if not token[0].isdigit() and not token[-1].isdigit(): # removes numbers
                        stemmed_tokens = stemmer.stem(token)
                        cleaned_tokens.append(stemmed_tokens)
        # add process article
        article_list.append(' '.join(wd for wd in cleaned_tokens))

    # echo results and return
    print 'preprocessed content for %d articles' % len(article_list)
    return article_list

# %%
cleaned_tokenized_stemmed_lemmatized_articles = preprocess_article_content(all_articles_df)
# Out:
# preprocessing article text...
# preprocessed content for 3 articles

# %%
len(cleaned_tokenized_stemmed_lemmatized_articles)
# Out:
# 3

# %% [markdown]
# ## Vectorize the bag of words (token count)

# %%
# can do feature(token) reduction later for too rare and too common words

vectorizer = CountVectorizer()

# perform count-based vectorization
article_vect = vectorizer.fit_transform(cleaned_tokenized_stemmed_lemmatized_articles)

# Kaggle method 
train_data_features = article_vect.toarray()

# %% [markdown]
# ## Take a look at the vocabulary

# %%
# Look at the vocabulary
vocab = vectorizer.get_feature_names()

# Look at the counts for each word
dist = np.sum(train_data_features, axis = 0)
for tag, count in zip(vocab, dist):
    print count, tag
# Out:
# 2 ad
# 1 adr
# 1 afford
# 1 alphabet
# 10 analyst
# 2 android
# 12 announc
# 1 answer
# 2 approach
# 2 april
# 1 around
# 1 augment
# 4 averag
# 2 back
# 1 bad
# 7 barra
# 2 base
# 2 beat
# 2 beaten
# 1 began
# 1 begin
# 1 beij
# 1 belief
# 1 billion
# 1 bought
# 1 brendan
# 2 bring
# 2 call
# 4 came
# 2 cap
# 2 ceo
# 1 ces
# 6 chang
# 1 china
# 1 chines
# 1 claim
# 2 climb
# 2 close
# 4 compani
# 2 compar
# 1 compel
# 1 complaint
# 1 comput
# 16 consensus
# 3 consum
# 1 continu
# 1 control
# 1 copyright
# 1 corp
# 2 cover
# 1 critic
# 4 data
# 2 date
# 12 day
# 1 decemb
# 2 declar
# 2 declin
# 1 detail
# 3 develop
# 1 devic
# 4 divis
# 4 drop
# 32 earn
# 3 effort
# 1 electron
# 4 end
# 2 ep
# 2 equiti
# 12 estim
# 1 excit
# 8 expect
# 1 experienc
# 8 facebook
# 1 fade
# 1 familiar
# 9 fb
# 2 februari
# 1 feel
# 2 fell
# 2 financi
# 2 firm
# 2 fiscal
# 1 fit
# 8 follow
# 2 founder
# 2 four
# 2 fourth
# 3 gain
# 1 game
# 1 gave
# 2 giant
# 2 given
# 2 go
# 1 googl
# 2 headset
# 2 help
# 1 high
# 2 higher
# 2 hire
# 4 histori
# 7 hugo
# 1 hype
# 1 imag
# 6 inc
# 2 includ
# 2 industri
# 1 innov
# 1 irib
# 2 januari
# 2 join
# 2 juli
# 1 kickstart
# 2 known
# 14 last
# 1 lawsuit
# 4 lead
# 1 leav
# 2 level
# 1 like
# 1 limitless
# 1 long
# 1 look
# 2 low
# 2 luckey
# 2 made
# 2 major
# 1 manag
# 1 mark
# 8 market
# 1 may
# 2 met
# 1 million
# 4 month
# 2 move
# 1 much
# 1 name
# 7 nasdaq
# 4 near
# 2 new
# 1 news
# 3 next
# 1 night
# 2 novemb
# 1 nyse
# 2 occas
# 9 oculus
# 2 offici
# 1 oper
# 1 order
# 1 palmer
# 1 part
# 1 particular
# 7 past
# 1 peopl
# 12 per
# 10 percent
# 4 period
# 1 platform
# 1 playstat
# 1 polish
# 1 polit
# 8 posit
# 2 post
# 2 present
# 1 presid
# 1 press
# 19 price
# 1 prior
# 2 probabl
# 2 product
# 4 project
# 1 promot
# 1 prospect
# 2 public
# 2 push
# 16 quarter
# 6 rang
# 2 reaction
# 1 readi
# 5 realiti
# 2 rebound
# 4 recent
# 2 record
# 2 releas
# 2 relev
# 8 report
# 2 respond
# 6 result
# 1 return
# 1 reveal
# 14 revenu
# 2 rift
# 3 right
# 1 root
# 1 rough
# 1 said
# 1 secret
# 2 seem
# 2 send
# 1 serv
# 2 session
# 25 share
# 3 short
# 1 show
# 1 silicon
# 2 sinc
# 2 six
# 1 skill
# 1 someon
# 1 soni
# 1 sound
# 1 start
# 1 step
# 12 stock
# 1 stole
# 2 street
# 1 struggl
# 10 surpris
# 1 system
# 2 target
# 1 team
# 3 technolog
# 2 tell
# 6 th
# 1 thing
# 1 though
# 1 tie
# 8 time
# 1 togeth
# 1 took
# 5 top
# 1 touch
# 1 traction
# 7 trade
# 2 trader
# 1 turn
# 1 understand
# 1 unexpect
# 2 us
# 1 valley
# 4 versus
# 1 veteran
# 1 vice
# 1 view
# 1 violat
# 5 virtual
# 2 volum
# 6 vr
# 2 wall
# 1 want
# 5 week
# 2 well
# 1 western
# 1 work
# 1 wrote
# 3 xiaomi
# 3 year
# 2 zuckerberg

# %%
def data_directory_crawl(path, ticker):
    """
    Crawls through a given parent directory to create a dataframe of articles and their body for the given company ticker
    """

    mypath = path + ticker + '/'
    company_articles_combined_days=pd.DataFrame()

    for directory in os.listdir(mypath):
    #     print directory
        f = []
        d = []
        for (dirpath, dirnames, filenames) in os.walk(mypath + directory):
            f.extend(filenames)
            d.extend(dirnames)

        company_articles_combined_days = company_articles_combined_days.append(read_Google_articles(f, mypath + directory + '/'))
    
    return company_articles_combined_days

# %% [markdown]
# # Fit a Random Forest Model to Data

# %%
FB_jan25_26 = np.asarray([131.48, 132.78, 133], dtype="|S6")

# Try random forest on bag of words
forest = RandomForestClassifier(n_estimators=100)
# fit the forest to the training set, using the bag of words features
forest = forest.fit(train_data_features, FB_jan25_26)

# %% [markdown]
# # Creating a Submission

# %% [markdown]
# ## Iterate through all days for given company to create dataframe

# %%
mypath = '/home/daisyz/Dropbox/finance_prediction/data/'
ticker = 'AAPL'

company_articles_combined_days = data_directory_crawl(mypath, ticker)
company_articles_combined_days
# Out:
#                                                  body           category  \
# 0   On today’s episode of the Zacks Friday Finish ...          Apple Inc
# 1   On today’s episode of the Zacks Friday Finish ...          Apple Inc
# 2   U.S. stock futures are pointed lower this morn...          Apple Inc
# 3   While Apple (NASDAQ:AAPL) requests for concess...          Apple Inc
# 4   Apple (AAPL) : In a disclosure report filed on...          Apple Inc
# 5   Apple (AAPL) will release their earnings for t...          Apple Inc
# 6   Leading the Apple Inc. (NASDAQ: ) rumor mill t...          Apple Inc
# 7   Apple is down 0.07% at $119.92 a share followi...          Apple Inc
# 8   Cowen maintains Outperform on Qualcomm (NASDAQ...          Apple Inc
# 9   The first day of public trading with President...          Apple Inc
# 10  Technology stocks still were edging lower duri...          Apple Inc
# 11  Apple Inc. (NASDAQ: ) dropped a bombshell on o...          Apple Inc
# 12  The smart home market continues to heat up, an...          Apple Inc
# 13  When Apple Inc. (NASDAQ: ) designed the iPhone...          Apple Inc
# 14  Two Securities and Exchanges Commission filing...          Apple Inc
# 15  Apple Inc. (AAPL) executives were in India tod...          Apple Inc
# 16  Robert W. Baird reaffirmed their outperform ra...          Apple Inc
# 17  Bernstein maintains Outperform on Apple (NASDA...          Apple Inc
# 18  It’s a pretty safe bet at this point that Appl...          Apple Inc
# 19  Despite being relatively weak compared to its ...          Apple Inc
# 20  I have to admit straight off the bat that I’m ...          Apple Inc
# 21  Reportedly, Apple Inc.’s AAPL management is sc...          Apple Inc
# 22  Consumer electronics giant Samsung (SSNLF) has...          Apple Inc
# 23  U.S. stock futures are in rally mode this morn...          Apple Inc
# 24  Check out which companies are making headlines...          Apple Inc
# 25  Apple (AAPL) : In a disclosure report filed on...          Apple Inc
# 26  BlackRock, a.k.a. the world’s largest asset ma...          Apple Inc
# 27  Apple Inc. (AAPL) stock was little changed in ...          Apple Inc
# 28  Credit Suisse maintains Outperform on Apple (N...          Apple Inc
# 29  Apple (AAPL) : In a disclosure report filed on...          Apple Inc
# ..                                                ...                ...
# 0   On today’s episode of the Zacks Friday Finish ...  Apple Inc 1-26-17
# 1   On today’s episode of the Zacks Friday Finish ...  Apple Inc 1-26-17
# 2   U.S. stock futures are pointed lower this morn...  Apple Inc 1-26-17
# 3   We have gathered the technical data on Apple I...  Apple Inc 1-26-17
# 4   Traders sold shares of Apple Inc. (NASDAQ:AAPL...  Apple Inc 1-26-17
# 5   Technology stocks fell for the first time this...  Apple Inc 1-26-17
# 6   In the annals of business relationships, the o...  Apple Inc 1-26-17
# 7   Apple (AAPL) will release their earnings for t...  Apple Inc 1-26-17
# 8   Leading the Apple Inc. (NASDAQ: ) rumor mill t...  Apple Inc 1-26-17
# 9   Leading the Apple Inc. (NASDAQ: ) rumor mill t...  Apple Inc 1-26-17
# 10  Apple is down 0.07% at $119.92 a share followi...  Apple Inc 1-26-17
# 11  Cowen maintains Outperform on Qualcomm (NASDAQ...  Apple Inc 1-26-17
# 12  The first day of public trading with President...  Apple Inc 1-26-17
# 13  Technology stocks still were edging lower duri...  Apple Inc 1-26-17
# 14  Apple Inc. (NASDAQ: ) dropped a bombshell on o...  Apple Inc 1-26-17
# 15  When Apple Inc. (NASDAQ: ) designed the iPhone...  Apple Inc 1-26-17
# 16  Two Securities and Exchanges Commission filing...  Apple Inc 1-26-17
# 17  Apple Inc. (AAPL) executives were in India tod...  Apple Inc 1-26-17
# 18  Bernstein maintains Outperform on Apple (NASDA...  Apple Inc 1-26-17
# 19  I have to admit straight off the bat that I’m ...  Apple Inc 1-26-17
# 20  Reportedly, Apple Inc.’s AAPL management is sc...  Apple Inc 1-26-17
# 21  Consumer electronics giant Samsung (SSNLF) has...  Apple Inc 1-26-17
# 22  U.S. stock futures are in rally mode this morn...  Apple Inc 1-26-17
# 23  Check out which companies are making headlines...  Apple Inc 1-26-17
# 24  Apple, Inc. AAPL is set to report its first-qu...  Apple Inc 1-26-17
# 25  On Tuesday Apple Inc. (AAPL) announced its iOS...  Apple Inc 1-26-17
# 26  BlackRock, a.k.a. the world’s largest asset ma...  Apple Inc 1-26-17
# 27  Apple Inc. (AAPL) stock was little changed in ...  Apple Inc 1-26-17
# 28  Looking at options trading activity among comp...  Apple Inc 1-26-17
# 29  With the 45th President of the United States v...  Apple Inc 1-26-17
#
#                                                 title
# 0   Tech Earnings Preview: Will AAPL, MSFT, GOOGL,...
# 1   Tech Earnings Preview: Will AAPL, MSFT, GOOGL,...
# 2   Monday’s Vital Data: Apple Inc. (AAPL), Rite A...
# 3    Apple, India reported nearing manufacturing deal
# 4   Reilly Financial Advisors Cuts Position in App...
# 5    Apple Earnings Strategy: When To Buy AAPL Shares
# 6   Wednesday Apple Rumors: AAPL May Use Flexible ...
# 7   Apple slips after being downgraded at Barclays...
# 8   Draconian Apple (AAPL) Case Suggests Limited Q...
# 9   3 Stocks to Watch on Tuesday: Apple Inc. (AAPL...
# 10  Technology Sector Update for 01/23/2017: HMNY,...
# 11  Apple Inc. (AAPL) Suit Against Qualcomm, Inc. ...
# 12  Alphabet Inc (GOOGL) Steals AI Expert Back Fro...
# 13  Apple Inc. (AAPL) iPhone Takes a Hit From ... ...
# 14  Tim Cook sells $7.2M worth of AAPL shares this...
# 15  Apple Close to Signing Deal With Indian Govern...
# 16  Apple Inc. (AAPL) Given Outperform Rating at R...
# 17  Apple's (AAPL) Downside Revisions Don't Matter...
# 18  Apple Inc. New iPads Might Be Late to the Part...
# 19                         Apple: No Safety, No Value
# 20     Apple Inc. (AAPL) Stock Can't Please Everybody
# 21  Apple (AAPL) Set to Meet Government Officials ...
# 22  Samsung Says Faulty Batteries Were Behind Note...
# 23  Wednesday’s Vital Data: Apple Inc. (AAPL), Fac...
# 24  Early movers: BA, UTX, TXT, AAPL, GPS, JBLU & ...
# 25  Private Bank Trust Co Boosts Position by $5,28...
# 26  World's largest investment firm goes even bigg...
# 27  Apple Inc. (AAPL) Stock Downgraded Ahead Of Ea...
# 28  Credit Suisse Says FX To Impact Apple (AAPL) E...
# 29  Warren Averett Asset Management Boosts Positio...
# ..                                                ...
# 0   Tech Earnings Preview: Will AAPL, MSFT, GOOGL,...
# 1   Tech Earnings Preview: Will AAPL, MSFT, GOOGL,...
# 2   Monday’s Vital Data: Apple Inc. (AAPL), Rite A...
# 3   Looking at the Tea Leaves for Apple Inc. (AAPL...
# 4   Investors Sell Apple Inc. (AAPL) on Strength A...
# 5   Technology Sector Update for 01/26/2017: LPL,A...
# 6       How Apple vs. Qualcomm Fits Business Strategy
# 7    Apple Earnings Strategy: When To Buy AAPL Shares
# 8   Thursday Apple Rumors: AAPL May Be Planning a ...
# 9   Wednesday Apple Rumors: AAPL May Use Flexible ...
# 10  Apple slips after being downgraded at Barclays...
# 11  Draconian Apple (AAPL) Case Suggests Limited Q...
# 12  3 Stocks to Watch on Tuesday: Apple Inc. (AAPL...
# 13  Technology Sector Update for 01/23/2017: HMNY,...
# 14  Apple Inc. (AAPL) Suit Against Qualcomm, Inc. ...
# 15  Apple Inc. (AAPL) iPhone Takes a Hit From ... ...
# 16  Tim Cook sells $7.2M worth of AAPL shares this...
# 17  Apple Close to Signing Deal With Indian Govern...
# 18  Apple's (AAPL) Downside Revisions Don't Matter...
# 19     Apple Inc. (AAPL) Stock Can't Please Everybody
# 20  Apple (AAPL) Set to Meet Government Officials ...
# 21  Samsung Says Faulty Batteries Were Behind Note...
# 22  Wednesday’s Vital Data: Apple Inc. (AAPL), Fac...
# 23  Early movers: BA, UTX, TXT, AAPL, GPS, JBLU & ...
# 24  Apple (AAPL) Q1 Earnings: What's in the Cards ...
# 25  Can Apple's (AAPL) "Find my Airpod" Feature Re...
# 26  World's largest investment firm goes even bigg...
# 27  Apple Inc. (AAPL) Stock Downgraded Ahead Of Ea...
# 28  Noteworthy Wednesday Option Activity: AAPL, CA...
# 29  Tech Stock Roundup: AAPL-QCOM Deal, FB's Zucke...
#
# [122 rows x 3 columns]

# %%
# create dictionary for each company. Each entry is a combined, cleaned
# string of all articles

days = set(company_articles_combined_days.category)

tokenized_daily_articles = dict()

for day in days:
    indiv_day_articles = company_articles_combined_days.loc[(company_articles_combined_days.category == day)]
    tokenized_daily_articles[day] = preprocess_article_content(indiv_day_articles)
# Out:
# preprocessing article text...
# preprocessed content for 31 articles
# preprocessing article text...
# preprocessed content for 32 articles
# preprocessing article text...
# preprocessed content for 30 articles
# preprocessing article text...
# preprocessed content for 29 articles

# %%
tokenized_daily_articles.keys()
# Out:
# [u'Apple Inc 1-27-17',
#  u'Apple Inc',
#  u'Apple Inc 1-26-17',
#  u'Apple Inc 1-30-17']

# %%
# Do this for every key in the dictionary
# can do feature(token) reduction later for too rare and too common words
# reshape df for word2vec

vectorizer = CountVectorizer()

# perform count-based vectorization
article_vect = vectorizer.fit_transform(tokenized_daily_articles['Apple Inc'])

# Kaggle method 
train_data_features = article_vect.toarray()

# %%
def preprocess_article_content_word2vec(text_df, remove_stopwords = False):
    """
    Simple preprocessing pipeline which uses RegExp, sets basic token requirements, and removes stop words.
    Set up to work with df files created from JSONs
    """
    print 'preprocessing article text...'

    # tokenizer, stops, and stemmer
    tokenizer = RegexpTokenizer(r'\w+')
    stemmer = SnowballStemmer('english')
    
    if remove_stopwords:
        stop_words = set(stopwords.words('english'))  # can add more stop words to this set
    else:
        stop_words = set()
        
    # process articles
    article_list = []
    for row, article in enumerate(text_df['body']):
        cleaned_tokens = []

        letters_only = re.sub("[^a-zA-Z]", " ", article)
        lower_case = letters_only.lower()
        tokens = tokenizer.tokenize(lower_case)

    #         tokens = tokenizer.tokenize(article.decode('utf-8').lower())
        for token in tokens:
            if token not in stop_words:
                if len(token) > 0 and len(token) < 20: # removes non words
                    if not token[0].isdigit() and not token[-1].isdigit(): # removes numbers
                        stemmed_tokens = stemmer.stem(token)
                        cleaned_tokens.append(stemmed_tokens)
        # add process article
        article_list.append(' '.join(wd for wd in cleaned_tokens))

    # echo results and return
    print 'preprocessed content for %d articles' % len(article_list)
    return article_list
