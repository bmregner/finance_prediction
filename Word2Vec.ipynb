# %%
import pandas as pd
import ijson
import json
import gensim
import re
import numpy as np
import os
import nltk.data

# from os import walk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
def read_Google_articles(articlelist, path):
    """ 
    Converts Google News JSON file into a data frame. Takes in
    a .json file and returns a dataframe using the json's dictionary-like
    structure 
    """
    
    with open(path + articlelist[0],'r') as first:
        firstdict = json.load(first)
        combined_df = pd.DataFrame.from_dict(firstdict, orient = 'index')
        combined_df = combined_df.T
    
    for article in articlelist:
        with open(path + article, 'r') as fin:
            mydict = json.load(fin)
        current_df = pd.DataFrame.from_dict(mydict, orient = 'index')
        current_df = current_df.T
        combined_df = combined_df.append(current_df, ignore_index=True)
    
    # USE CONCAT WITH .APPEND DOESN'T WORK!!!
#     final_df = pd.concat([combined_df, current_df])
        
    return combined_df

# %%
def data_directory_crawl(path, ticker):
    """
    Crawls through a given parent directory to create a dataframe of articles and their body for the given company ticker
    """

    mypath = path + ticker + '/'
    company_articles_combined_days=pd.DataFrame()

    for directory in os.listdir(mypath):
    #     print directory
        f = []
        d = []
        for (dirpath, dirnames, filenames) in os.walk(mypath + directory):
            f.extend(filenames)
            d.extend(dirnames)

        company_articles_combined_days = company_articles_combined_days.append(read_Google_articles(f, mypath + directory + '/'))
    
    return company_articles_combined_days

# %%
def preprocess_article_content_wordlist(text_df, remove_stopwords = False):
    """
    Simple preprocessing pipeline which uses RegExp, sets basic token requirements, and removes stop words.
    Set up to work with df files created from JSONs
    """
    print 'preprocessing article text...'

#     # tokenizer, stops, and stemmer
#     tokenizer = RegexpTokenizer(r'\w+')
#     stemmer = SnowballStemmer('english')
    
    if remove_stopwords:
        stop_words = set(stopwords.words('english'))  # can add more stop words to this set
    else:
        stop_words = set()
        
    # process articles
    article_list = []
    for row, article in enumerate(text_df['body']):
        cleaned_tokens = []

        letters_only = re.sub("[^a-zA-Z]", " ", article)
        lower_case_words = letters_only.lower().split()
#         tokens = tokenizer.tokenize(lower_case)
        lower_case_words = [w for w in lower_case_words if not w in stop_words]

#         for token in tokens:
#             if token not in stop_words:
#                 if len(token) > 0 and len(token) < 20: # removes non words
#                     if not token[0].isdigit() and not token[-1].isdigit(): # removes numbers
#                         stemmed_tokens = stemmer.stem(token)
#                         cleaned_tokens.append(stemmed_tokens)
        # add process article
#         article_list.append(' '.join(wd for wd in cleaned_tokens))

    # echo results and return
    print 'preprocessed content for %d words' % len(lower_case_words)
    return lower_case_words

# %% [markdown]
# # Creating a Submission
# ## Iterate through all days for a given company to create a dataframe

# %%
mypath = '/home/daisyz/Dropbox/finance_prediction/data/'
ticker = 'AAPL'

company_articles_combined_days = data_directory_crawl(mypath, ticker)
company_articles_combined_days
# Out:
#                                                  body           category  \
# 0   Apple (AAPL) CEO Tim Cook says his company had...   Apple Inc 2-1-17
# 1   Apple (AAPL) CEO Tim Cook says his company had...   Apple Inc 2-1-17
# 2   Check out which companies are making headlines...   Apple Inc 2-1-17
Tech Earnings Preview: Will AAPL, MSFT, GOOGL,...
# 1   Tech Earnings Preview: Will AAPL, MSFT, GOOGL,...
# 2   Monday’s Vital Data: Apple Inc. (AAPL), Rite A...
# 3   Looking at the Tea Leaves for Apple Inc. (AAPL...
# 4   Investors Sell Apple Inc. (AAPL) on Strength A...
# 5   Technology Sector Update for 01/26/2017: LPL,A...
# 6       How Apple vs. Qualcomm Fits Business Strategy
# 7    Apple Earnings Strategy: When To Buy AAPL Shares
# 8   Thursday Apple Rumors: AAPL May Be Planning a ...
# 9   Wednesday Apple Rumors: AAPL May Use Flexible ...
# 10  Apple slips after being downgraded at Barclays...
# 11  Draconian Apple (AAPL) Case Suggests Limited Q...
# 12  3 Stocks to Watch on Tuesday: Apple Inc. (AAPL...
# 13  Technology Sector Update for 01/23/2017: HMNY,...
# 14  Apple Inc. (AAPL) Suit Against Qualcomm, Inc. ...
# 15  Apple Inc. (AAPL) iPhone Takes a Hit From ... ...
# 16  Tim Cook sells $7.2M worth of AAPL shares this...
# 17  Apple Close to Signing Deal With Indian Govern...
# 18  Apple's (AAPL) Downside Revisions Don't Matter...
# 19     Apple Inc. (AAPL) Stock Can't Please Everybody
# 20  Apple (AAPL) Set to Meet Government Officials ...
# 21  Samsung Says Faulty Batteries Were Behind Note...
# 22  Wednesday’s Vital Data: Apple Inc. (AAPL), Fac...
# 23  Early movers: BA, UTX, TXT, AAPL, GPS, JBLU & ...
# 24  Apple (AAPL) Q1 Earnings: What's in the Cards ...
# 25  Can Apple's (AAPL) "Find my Airpod" Feature Re...
# 26  World's largest investment firm goes even bigg...
# 27  Apple Inc. (AAPL) Stock Downgraded Ahead Of Ea...
# 28  Noteworthy Wednesday Option Activity: AAPL, CA...
# 29  Tech Stock Roundup: AAPL-QCOM Deal, FB's Zucke...
#
# [175 rows x 3 columns]

# %%
# create dictionary for each company. Each entry is a combined, cleaned
# string of all articles

days = set(company_articles_combined_days.category)
daily_articles_body = pd.DataFrame(columns = ('category', 'full_text'))

for j, day in enumerate(days):
    indiv_day_articles = company_articles_combined_days.loc[(company_articles_combined_days.category == day)]
    all_body = []
    for i in range(0,len(indiv_day_articles)):
        all_body.append(indiv_day_articles.body.iloc[i])
#         print all_body
#     d = [day, all_body]
#     print d
#     temp_df = pd.DataFrame(d, columns = ('category', 'full_text'))
#     print(temp_df)
#     daily_articles_body = pd.DataFrame(all_body, index = day, columns = ('category', 'full_text'))

# %%
daily_listed_articles = company_articles_combined_days.groupby('category')['body'].apply(list)
pd.DataFrame(daily_listed_articles)
# Out:
#                                                                 body
# category
# Apple Inc          [On today’s episode of the Zacks Friday Finish...
# Apple Inc 1-26-17  [On today’s episode of the Zacks Friday Finish...
# Apple Inc 1-27-17  [On today’s episode of the Zacks Friday Finish...
# Apple Inc 1-30-17  [On Tuesday, January 31st, Apple (AAPL) will r...
# Apple Inc 1-31-17  [Apple (NASDAQ:AAPL) reported earnings on Tues...
# Apple Inc 2-1-17   [Apple (AAPL) CEO Tim Cook says his company ha...

# %%
# Load the punkt tokenizer
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
# Define a function to split dictionary into parsed sentences
def word_dict_to_sentences(dictionary_entry, tokenizer, remove_stopwords = False):
    """ Function takes dictionary with combined strings from all articles from 
    multiple days (row = day, words = singular words combined from all articles. 
    """
    
# 1. Use NLTK tokenizer to split the paragraph into sentences.
    raw_sentences = tokenizer.tokenize(dictionary_entry.strip())
    
# 2. Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
#         skip an empty sentence
        if len(raw_sentence) > 0:
            sentences.append(raw_sentence)
            
    # return a list of lists (List of sentences, each sentence is a list of words)
    return sentences

# %%
sentences = []
path = mypath = '/home/daisyz/Dropbox/finance_prediction/data/AAPL/'

print "Parsing sentences"
for key in indiv_day_articles:
    indiv_day_articles[key] = word_dict_to_sentences(indiv_day_articles.body.iloc[0], tokenizer)
# Out:
# Parsing sentences
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-22305de832b6> in <module>()
#       4 print "Parsing sentences"
#       5 for key in indiv_day_articles:
# ----> 6     indiv_day_articles[key] = word_dict_to_sentences(indiv_day_articles.body.iloc[0], tokenizer)
#
# /home/daisyz/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2355         else:
#    2356             # set column
# -> 2357             self._set_item(key, value)
#    2358
#    2359     def _setitem_slice(self, key, value):
#
# /home/daisyz/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    2421
#    2422         self._ensure_valid_index(value)
# -> 2423         value = self._sanitize_column(key, value)
#    2424         NDFrame._set_item(self, key, value)
#    2425
#
# /home/daisyz/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value)
#    2576
#    2577             # turn me into an ndarray
# -> 2578             value = _sanitize_index(value, self.index, copy=False)
#    2579             if not isinstance(value, (np.ndarray, Index)):
#    2580                 if isinstance(value, list) and len(value) > 0:
#
# /home/daisyz/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in _sanitize_index(data, index, copy)
#    2768
#    2769     if len(data) != len(index):
# -> 2770         raise ValueError('Length of values does not match length of ' 'index')
#    2771
#    2772     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
indiv_day_articles
# Out:
#                                                  body           category  \
# 0   On Tuesday, January 31st, Apple (AAPL) will re...  Apple Inc 1-30-17
# 1   On Tuesday, January 31st, Apple (AAPL) will re...  Apple Inc 1-30-17
# 2   Chicago Equity Partners Llc decreased its stak...  Apple Inc 1-30-17
# 3   In the annals of business relationships, the o...  Apple Inc 1-30-17
# 4   Apple (AAPL) will release their earnings for t...  Apple Inc 1-30-17
# 5   There are 3 sell ratings, 8 hold ratings, 37 b...  Apple Inc 1-30-17
# 6   Leading the Apple Inc. (NASDAQ: ) rumor mill t...  Apple Inc 1-30-17
# 7   Leading the Apple Inc. (NASDAQ: ) rumor mill t...  Apple Inc 1-30-17
# 8   Apple Inc. (NASDAQ: ) dropped a bombshell on o...  Apple Inc 1-30-17
# 9   When Apple Inc. (NASDAQ: ) designed the iPhone...  Apple Inc 1-30-17
# 10  Continued volatility in global markets and rec...  Apple Inc 1-30-17
# 11  In what can only be perceived as an unusual mo...  Apple Inc 1-30-17
# 12  When Apple announces its sales and revenue fig...  Apple Inc 1-30-17
# 13  Last quarter, Apple announced an annual declin...  Apple Inc 1-30-17
# 14  Rumors about the Apple car have been swirling ...  Apple Inc 1-30-17
# 15  Looking today at week-over-week shares outstan...  Apple Inc 1-30-17
# 16  Newport Beach, CA, based Investment company Al...  Apple Inc 1-30-17
# 17  Leading the Apple Inc. (NASDAQ: ) rumor mill t...  Apple Inc 1-30-17
# 18  Value investing is easily one of the most popu...  Apple Inc 1-30-17
# 19  U.S. stock futures are in rally mode this morn...  Apple Inc 1-30-17
# 20  Apple Inc. (NASDAQ:AAPL) belonging to the Comp...  Apple Inc 1-30-17
# 21  Check out which companies are making headlines...  Apple Inc 1-30-17
# 22  On Tuesday Apple Inc. (AAPL) announced its iOS...  Apple Inc 1-30-17
# 23  Before earnings hit tomorrow, UBS steps back a...  Apple Inc 1-30-17
# 24  Wall Street renowned brokerages following Appl...  Apple Inc 1-30-17
# 25  Apple Inc. (NASDAQ:AAPL)‘s iPhones and devices...  Apple Inc 1-30-17
# 26  In technology stocks news, Digital Ally ( DGLY...  Apple Inc 1-30-17
# 27  Barclays downgraded Apple (NASDAQ: AAPL) from ...  Apple Inc 1-30-17
# 28  With the 45th President of the United States v...  Apple Inc 1-30-17
#
#                                                 title
# 0   Bartosiak: Trading Apple's (AAPL) Earnings wit...
# 1   Bartosiak: Trading Apple's (AAPL) Earnings wit...
# 2   Chicago Equity Partners LLC Position in Apple ...
# 3       How Apple vs. Qualcomm Fits Business Strategy
# 4    Apple Earnings Strategy: When To Buy AAPL Shares
# 5   Analyst Activity – Drexel Hamilton Reiterates ...
# 6   Thursday Apple Rumors: AAPL May Be Planning a ...
# 7   Wednesday Apple Rumors: AAPL May Use Flexible ...
# 8   Apple Inc. (AAPL) Suit Against Qualcomm, Inc. ...
# 9   Apple Inc. (AAPL) iPhone Takes a Hit From ... ...
# 10  AAPL Opens Below $100 for the First Time Since...
# 11  Apple Inc. (NASDAQ:AAPL) Removes Activation Lo...
# 12  Will AAPL return to growth in Q1, or will it r...
# 13  What to expect from Apple’s first-quarter earn...
# 14  These Apple Car Concepts Are Inspired By AAPL'...
# 15  DIA, BA, AAPL, MCD: Large Inflows Detected at ETF
# 16  Jan 30, 2017 - Alpha Cubed Investments, LLC Bu...
# 17  Monday Apple Rumors: AAPL Is Taking Down Apps ...
# 18  Can Apple (AAPL) be a Suitable Value Pick at t...
# 19  Wednesday’s Vital Data: Apple Inc. (AAPL), Fac...
# 20         Hot Stock Update: Apple Inc. (NASDAQ:AAPL)
# 21  Early movers: BA, UTX, TXT, AAPL, GPS, JBLU & ...
# 22  Can Apple's (AAPL) "Find my Airpod" Feature Re...
# 23  What is the Right P/E Multiple for Apple Inc. ...
# 24  The Growth Forecast For Apple Inc. (NASDAQ:AAP...
# 25  Apple Inc. (AAPL) Forfeits Top Spot to Android...
# 26  Technology Sector Update for 01/30/2017: MSFT,...
# 27  Barclays Downgrades Apple (AAPL) to Equalweigh...
# 28  Tech Stock Roundup: AAPL-QCOM Deal, FB's Zucke...
